# %%
import pandas as pd

# %%
Data = pd.read_csv("newdataset.csv")
Data
# Out:
#        Region      Sation Month  Year  SQ2   NOx PM10 PM2.5  NH3   AQI
# 0    Adilabad  Mandamarri   JAN  2022  NaN   NaN  NaN   NaN  NaN   NaN
# 1    Adilabad  Mandamarri   FEB  2022  NaN   NaN  NaN   NaN  NaN   NaN
# 2    Adilabad  Mandamarri   MAR  2022  8.2  25.6   56   NaN   14  56.0
# 3    Adilabad  Mandamarri   APR  2022  9.5  28.2   65   NaN   18  65.0
# 4    Adilabad  Mandamarri   MAY  2022  7.9  26.5   60   NaN   14  60.0
# ..        ...         ...   ...   ...  ...   ...  ...   ...  ...   ...
# 583   Khammam   Jalasouda   AUG  2016    5    14   37   NaN   20  37.0
# 584   Khammam   Jalasouda   SEP  2016    8    17   39   NaN   21  39.0
# 585   Khammam   Jalasouda   OCT  2016    7    23   48   NaN   21  48.0
# 586   Khammam   Jalasouda   NOV  2016    7    24   55   NaN   28  55.0
# 587   Khammam   Jalasouda   DEC  2016    8    27   60   NaN   22  60.0
#
# [588 rows x 10 columns]

# %%
# Selecting Region ,Month and Year Column 
Data = Data[['Region','Month','Year']]

# %%
Data
# Out:
#        Region Month  Year
# 0    Adilabad   JAN  2022
# 1    Adilabad   FEB  2022
# 2    Adilabad   MAR  2022
# 3    Adilabad   APR  2022
# 4    Adilabad   MAY  2022
# ..        ...   ...   ...
# 583   Khammam   AUG  2016
# 584   Khammam   SEP  2016
# 585   Khammam   OCT  2016
# 586   Khammam   NOV  2016
# 587   Khammam   DEC  2016
#
# [588 rows x 3 columns]

# %%
from datetime import datetime

# Generating Starting Date and Ending Date of every month of every year
# using Month and Year column

Data['Start_Date'] = pd.to_datetime(Data['Month'] + ' ' + Data['Year'].astype(str))
Data['End_Date'] = pd.to_datetime(Data['Month'] + ' ' + Data['Year'].astype(str)) + pd.offsets.MonthEnd(1)

# Changing the format of the date 
# yy-mm-dd -->  dd-mm-yy

Data['Start_Date'] = Data['Start_Date'].dt.strftime('%d-%m-%y')
Data['End_Date'] = Data['End_Date'].dt.strftime('%d-%m-%y')
# Out:
# /tmp/ipykernel_38631/3714497256.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Start_Date'] = pd.to_datetime(Data['Month'] + ' ' + Data['Year'].astype(str))
# /tmp/ipykernel_38631/3714497256.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['End_Date'] = pd.to_datetime(Data['Month'] + ' ' + Data['Year'].astype(str)) + pd.offsets.MonthEnd(1)
# /tmp/ipykernel_38631/3714497256.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Start_Date'] = Data['Start_Date'].dt.strftime('%d-%m-%y')
# /tmp/ipykernel_38631/3714497256.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['End_Date'] = Data['End_Date'].dt.strftime('%d-%m-%y')

# %%
import datetime

# converting "dd-mm-yy" into UNIX time 
# Append the data to a new Start_Date_Unix column
unix_Startdate = []
for sd in Data['Start_Date']:
    s_dts = datetime.datetime.strptime(sd, "%d-%m-%y")
    unix_Startdate.append(int(s_dts.timestamp()))
Data['Start_Date_Unix'] = unix_Startdate

# converting "dd-mm-yy" into UNIX time
# Append the data to a new End_Date_Unix column
unix_Enddate = []
for ed in Data['End_Date']:
    e_dts = datetime.datetime.strptime(ed, "%d-%m-%y")
    unix_Enddate.append(int(e_dts.timestamp()))
Data['End_Date_Unix'] = unix_Enddate
# Out:
# /tmp/ipykernel_38631/3381727550.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Start_Date_Unix'] = unix_Startdate
# /tmp/ipykernel_38631/3381727550.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['End_Date_Unix'] = unix_Enddate

# %%
# Creating a Column with postfix location
Data['Full Location'] = Data.loc[:,('Region')] + ", Telangana, India"
Data
# Out:
# /tmp/ipykernel_38631/2975108895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['Full Location'] = Data.loc[:,('Region')] + ", Telangana, India"
#        Region Month  Year Start_Date  End_Date  Start_Date_Unix  \
# 0    Adilabad   JAN  2022   01-01-22  31-01-22       1640975400
# 1    Adilabad   FEB  2022   01-02-22  28-02-22       1643653800
# 2    Adilabad   MAR  2022   01-03-22  31-03-22       1646073000
# 3    Adilabad   APR  2022   01-04-22  30-04-22       1648751400
# 4    Adilabad   MAY  2022   01-05-22  31-05-22       1651343400
# ..        ...   ...   ...        ...       ...              ...
# 583   Khammam   AUG  2016   01-08-16  31-08-16       1469989800
# 584   Khammam   SEP  2016   01-09-16  30-09-16       1472668200
# 585   Khammam   OCT  2016   01-10-16  31-10-16       1475260200
# 586   Khammam   NOV  2016   01-11-16  30-11-16       1477938600
# 587   Khammam   DEC  2016   01-12-16  31-12-16       1480530600
#
#      End_Date_Unix               Full Location
# 0       1643567400  Adilabad, Telangana, India
# 1       1645986600  Adilabad, Telangana, India
# 2       1648665000  Adilabad, Telangana, India
# 3       1651257000  Adilabad, Telangana, India
# 4       1653935400  Adilabad, Telangana, India
# ..             ...                         ...
# 583     1472581800   Khammam, Telangana, India
# 584     1475173800   Khammam, Telangana, India
# 585     1477852200   Khammam, Telangana, India
# 586     1480444200   Khammam, Telangana, India
# 587     1483122600   Khammam, Telangana, India
#
# [588 rows x 8 columns]

# %%
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent="myGeocoder")

# Defining a function to get the latitude and longitude values of a given Full location
def getLatLong(loc):
   
    result = "Not Found"
    location = locator.geocode(loc)
    if(location != None):
        result = "lat={}&lon={}".format(location.latitude, location.longitude)
    return result

# Getting the latitude and longitude values 
# Apply the getLatLong function to the 'Full Location' column in Data, and create a new 'LatLong' column with the results
Data['LatLong'] = Data['Full Location'].apply(lambda x: getLatLong(x))
# Out:
# /tmp/ipykernel_38631/1237071010.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data['LatLong'] = Data['Full Location'].apply(lambda x: getLatLong(x))

# %%
# saving the data as csv file for future use
Data.to_csv("forapi.csv")

# %%
import urllib.request, urllib.parse, urllib.error
import json

# sample url of OpenWeather api
# http://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={API key} 

key = "c07a9fcaab2d950fbcc19fef00a77360"
serviceURL = "http://api.openweathermap.org/data/2.5/air_pollution/history?"

# %%
for index, row in Data.iterrows():
    # Extract the latitude and longitude from the LatLong column
    LatLong = row['LatLong']
    
    # Extract the start and end date in Unix format
    start_date = row['Start_Date_Unix']
    end_date = row['End_Date_Unix']
    
    # Construct the API URL with the required parameters
    url = f"{serviceURL}{LatLong}&start={start_date}&end={end_date}&appid={key}"
    
    # Send a request to the API URL and receive the response
    response = urllib.request.urlopen(url)
    
    # Parse the response JSON data into a dataframe    
    data = json.loads(response.read().decode())
    df = pd.json_normalize(data, record_path=['list'], meta=['coord'])
    
    # Append the data to a CSV file
    df.to_csv("data.csv", mode='a', header=False)

# %%
# Reading data from the csv file
Data = pd.read_csv("data.csv")
col = ["Date","AQI","CO","NO","NO2","O3","SO2","PM2.5","PM10","NH3","Coord"]

# %%
Data =Data.drop(["0"],axis=1)

# %%
Data.columns = col
Data
# Out:
#               Date  AQI      CO   NO    NO2     O3    SO2   PM2.5    PM10  \
# 0       1640980800    5  614.17  0.0  10.28  72.24  23.84  120.22  127.48
# 1       1640984400    5  614.17  0.0   8.31  75.10  20.74  122.38  128.89
# 2       1640988000    5  634.19  0.0   7.03  74.39  16.45  124.92  131.06
# 3       1640991600    5  647.54  0.0   6.17  67.95  11.92  125.66  131.56
# 4       1640995200    5  654.22  0.0   6.08  59.37   9.54  125.06  130.83
# ...            ...  ...     ...  ...    ...    ...    ...     ...     ...
# 246198  1609336800    5  614.17  0.0   9.51  57.94   4.17  166.48  174.98
# 246199  1609340400    5  634.19  0.0   9.17  52.21   3.70  169.40  178.33
# 246200  1609344000    5  620.84  0.0   8.23  50.07   3.49  163.43  172.44
# 246201  1609347600    5  587.46  0.0   7.28  55.79   4.05  148.19  157.18
# 246202  1609351200    5  547.41  0.0   6.51  70.81   5.48  134.60  143.72
#
#          NH3                          Coord
# 0       0.00     {'lon': 78.5, 'lat': 19.5}
# 1       0.00     {'lon': 78.5, 'lat': 19.5}
# 2       0.00     {'lon': 78.5, 'lat': 19.5}
# 3       0.25     {'lon': 78.5, 'lat': 19.5}
# 4       0.71     {'lon': 78.5, 'lat': 19.5}
# ...      ...                            ...
# 246198  5.13  {'lon': 80.3333, 'lat': 17.5}
# 246199  5.64  {'lon': 80.3333, 'lat': 17.5}
# 246200  5.83  {'lon': 80.3333, 'lat': 17.5}
# 246201  5.45  {'lon': 80.3333, 'lat': 17.5}
# 246202  4.18  {'lon': 80.3333, 'lat': 17.5}
#
# [246203 rows x 11 columns]

# %%
# converting the UNIX Date into "dd-mm-yy" format
formatted_date = []
for un in Data['Date']:
    dt = datetime.datetime.fromtimestamp(un)
    formatted_date.append(dt.strftime('%d-%m-%y'))
Data['Date'] = formatted_date

# %%
Data["Coord"].unique()
# Out:
# array(["{'lon': 78.5, 'lat': 19.5}", "{'lon': 78.25, 'lat': 18.75}",
#        "{'lon': 79.5971, 'lat': 17.9821}",
#        "{'lon': 79.1328, 'lat': 18.4348}",
#        "{'lon': 80.3333, 'lat': 17.5}"], dtype=object)

# %%
dic = {"{'lon': 78.5, 'lat': 19.5}":"Adilabad, Telangana, India", 
     "{'lon': 78.25, 'lat': 18.75}":"Nizamabad, Telangana, India",
       "{'lon': 79.5971, 'lat': 17.9821}":"Warangal, Telangana, India",
       "{'lon': 79.1328, 'lat': 18.4348}":"Karimnagar, Telangana, India",
       "{'lon': 80.3333, 'lat': 17.5}":"Khammam, Telangana, India"}

# %%
Data["Coord"] = Data["Coord"].map(dic)

# %%
Data = Data.rename(columns={'Coord': 'Location'})
# Data.to_csv("AQI_finaldataset.csv")

# %%
import pandas as pd
Data = pd.read_csv("AQI_finaldataset.csv")
# Convert the date column to pandas datetime object
Data['Date'] = pd.to_datetime(Data['Date'])

# Group the data by date and location, and calculate the mean values for each group
grouped_data = Data.groupby(['Date', 'Location']).mean()
# Reset the index of the grouped data to create a new dataframe with one row per date for each location
new_data = grouped_data.reset_index()

new_data.drop("Unnamed: 0",axis=1)
new_data.to_csv("AQI_finaldataset.csv",index=False)

# %%
import pandas as pd

Data = pd.read_csv("AQI_finaldataset.csv")

# %%
Data
# Out:
#             Date                      Location       AQI          CO  \
# 0     2020-01-12    Adilabad, Telangana, India  4.958333  456.175417
# 1     2020-01-12  Karimnagar, Telangana, India  5.000000  720.283333
# 2     2020-01-12     Khammam, Telangana, India  5.000000  463.965000
# 3     2020-01-12   Nizamabad, Telangana, India  4.875000  584.543333
# 4     2020-01-12    Warangal, Telangana, India  5.000000  641.704167
# ...          ...                           ...       ...         ...
# 3690  2022-12-30    Adilabad, Telangana, India  4.250000  537.116250
# 3691  2022-12-30  Karimnagar, Telangana, India  4.541667  779.669167
# 3692  2022-12-30     Khammam, Telangana, India  3.541667  375.231667
# 3693  2022-12-30   Nizamabad, Telangana, India  4.791667  600.952917
# 3694  2022-12-30    Warangal, Telangana, India  4.125000  516.254583
#
#             NO        NO2         O3        SO2       PM2.5        PM10  \
# 0     0.458333  11.532500  73.984583  14.119167   64.316667   71.244583
# 1     1.470000  17.677500  48.816667   7.001667  101.994167  115.704583
# 2     0.108750   6.395833  56.237083   3.274583   75.047500   81.250833
# 3     0.411250   9.455417  59.755000  10.259167   74.220000   87.468750
# 4     0.205417  15.177917  52.822500   6.458333   88.811250   98.957917
# ...        ...        ...        ...        ...         ...         ...
# 3690  0.551250  24.267500  51.432083  19.873750   68.129583   76.675000
# 3691  1.850000  27.073750  54.335000  14.355833   86.390000   99.132917
# 3692  0.342083   3.838333  48.545833   2.935000   52.775417   58.132917
# 3693  0.304167   8.980833  54.635417  12.270000   85.993333   98.587083
# 3694  0.433750   9.577500  50.820000   3.736667   66.760833   74.665833
#
#             NH3
# 0      7.498333
# 1     14.710833
# 2      3.192083
# 3     15.049583
# 4      5.284583
# ...         ...
# 3690   8.165000
# 3691  12.925833
# 3692   3.614583
# 3693  12.157083
# 3694   6.642083
#
# [3695 rows x 11 columns]

# %%
# Convert the floating-point data to integers using ceiling and floor
for column in Data.columns:
    if Data['AQI'].dtype == 'float64':
        Data['AQI'] = Data['AQI'].apply(lambda x: int(x) if x == int(x) else int(x) + 1 if x - int(x) >= 0.5 else int(x))

# Write the modified data back to a CSV file
Data.to_csv("AQI_finaldataset.csv", index=False)

# %%
import math


def calculate_aqi(so2_conc, O3_conc, no2_conc, pm10_conc, pm25_conc, nh3_conc):
    # Calculate AQI for each pollutant
    aqi_so2 = calculate_aqi_pollutant(so2_conc, "SO2")
    aqi_O3 = calculate_aqi_pollutant(O3_conc, "O3")
    aqi_no2 = calculate_aqi_pollutant(no2_conc, "NO2")
    aqi_pm10 = calculate_aqi_pollutant(pm10_conc, "PM10")
    aqi_pm25 = calculate_aqi_pollutant(pm25_conc, "PM2.5")
    aqi_nh3 = calculate_aqi_pollutant(nh3_conc, "NH3")

    

    # Determine the overall AQI by taking the maximum AQI value
    aqi = max(aqi_so2, aqi_O3, aqi_no2, aqi_pm10, aqi_pm25, aqi_nh3)
    
    # aqi = statistics.mea(aqi)
    return aqi


def calculate_aqi_pollutant(conc, pollutant):
# Calculate AQI for each pollutant
# Define the AQI breakpoints and corresponding values for each pollutant
    if pollutant == "SO2":
        breakpoints = [0, 35, 75, 185, 304, 604, 804, 1004]
        aqi_values = [0, 50, 100, 150, 200, 300, 400, 500]
    elif pollutant == "O3":
        breakpoints = [0, 54, 70, 85, 105, 200, 404, 504]
        aqi_values = [0, 50, 100, 150, 200, 300, 400, 500]
    elif pollutant == "NO2":
        breakpoints = [0, 53, 100, 360, 649, 1249, 1649, 2049]
        aqi_values = [0, 50, 100, 150, 200, 300, 400, 500]
    elif pollutant == "PM10":
        breakpoints = [0, 54, 154, 254, 354, 424, 504, 604]
        aqi_values = [0, 50, 100, 150, 200, 300, 400, 500]
    elif pollutant == "PM2.5":
        breakpoints = [0, 12, 35.4, 55.4, 150.4, 250.4, 350.4, 500.4]
        aqi_values = [0, 50, 100, 150, 200, 300, 400, 500]
    elif pollutant == "NH3":
        breakpoints = [0, 53, 100, 200, 400, 800, 1200, 1800]
        aqi_values = [0, 50, 100, 150, 200, 300, 400, 500]
    else:
        raise ValueError("Invalid pollutant type")

# Calculate the AQI for the given concentration value
    if conc <= breakpoints[0]:
        aqi = 0
    elif conc > breakpoints[-1]:
        aqi = 500
    else:
        for i in range(len(breakpoints)-1):
            if conc > breakpoints[i] and conc <= breakpoints[i+1]:
                aqi = (aqi_values[i+1] - aqi_values[i]) / (breakpoints[i+1] -  breakpoints[i]) * (conc - breakpoints[i]) + aqi_values[i]

    return math.ceil(aqi) if (aqi - math.floor(aqi)) >= 0.5 else math.floor(aqi)

# %%
# import pandas as pd
# Data = pd.read_csv("AQI_finaldataset.csv")

Data['AQI'] = Data.apply(lambda row: calculate_aqi(row['SO2'], row['O3'], row['NO2'], row['PM10'], row['PM2.5'], row['NH3']), axis=1)

# %%
Data.describe()
# Out:
#                AQI           CO           NO          NO2           O3  \
# count  3695.000000  3695.000000  3695.000000  3695.000000  3695.000000
# mean    117.671448   445.000330     0.291656     7.359507    57.598408
# std      59.774547   138.758077     0.443692     4.575958    24.297298
# min      17.000000   212.718750     0.000000     1.020417     7.666667
# 25%      56.000000   335.454792     0.092917     4.296667    35.290625
# 50%     136.000000   431.000833     0.154583     5.984167    57.877083
# 75%     166.000000   531.624167     0.300417     8.926250    76.062917
# max     281.000000  1008.173333     6.500000    37.692917   140.518333
#
#                SO2        PM2.5         PM10          NH3
# count  3695.000000  3695.000000  3695.000000  3695.000000
# mean      6.047629    49.331427    57.856255     5.534199
# std       5.168693    41.321719    45.204729     4.149772
# min       0.315000     1.704583     2.058333     0.027083
# 25%       2.574167    13.677917    16.761667     2.567917
# 50%       4.536667    39.387083    51.141250     4.480833
# 75%       7.499792    73.873333    87.512292     7.413542
# max      39.191250   231.400417   244.784583    30.095833

# %%
Data.to_csv("AQI_finaldataset.csv", index=False)
Data
# Out:
#             Date                      Location  AQI          CO        NO  \
# 0     2020-01-12    Adilabad, Telangana, India  155  456.175417  0.458333
# 1     2020-01-12  Karimnagar, Telangana, India  175  720.283333  1.470000
# 2     2020-01-12     Khammam, Telangana, India  160  463.965000  0.108750
# 3     2020-01-12   Nizamabad, Telangana, India  160  584.543333  0.411250
# 4     2020-01-12    Warangal, Telangana, India  168  641.704167  0.205417
# ...          ...                           ...  ...         ...       ...
# 3690  2022-12-30    Adilabad, Telangana, India  157  537.116250  0.551250
# 3691  2022-12-30  Karimnagar, Telangana, India  166  779.669167  1.850000
# 3692  2022-12-30     Khammam, Telangana, India  143  375.231667  0.342083
# 3693  2022-12-30   Nizamabad, Telangana, India  166  600.952917  0.304167
# 3694  2022-12-30    Warangal, Telangana, India  156  516.254583  0.433750
#
#             NO2         O3        SO2       PM2.5        PM10        NH3
# 0     11.532500  73.984583  14.119167   64.316667   71.244583   7.498333
# 1     17.677500  48.816667   7.001667  101.994167  115.704583  14.710833
# 2      6.395833  56.237083   3.274583   75.047500   81.250833   3.192083
# 3      9.455417  59.755000  10.259167   74.220000   87.468750  15.049583
# 4     15.177917  52.822500   6.458333   88.811250   98.957917   5.284583
# ...         ...        ...        ...         ...         ...        ...
# 3690  24.267500  51.432083  19.873750   68.129583   76.675000   8.165000
# 3691  27.073750  54.335000  14.355833   86.390000   99.132917  12.925833
# 3692   3.838333  48.545833   2.935000   52.775417   58.132917   3.614583
# 3693   8.980833  54.635417  12.270000   85.993333   98.587083  12.157083
# 3694   9.577500  50.820000   3.736667   66.760833   74.665833   6.642083
#
# [3695 rows x 11 columns]

# %%
Data["Location"].unique()
# Out:
# array(['Adilabad, Telangana, India', 'Karimnagar, Telangana, India',
#        'Khammam, Telangana, India', 'Nizamabad, Telangana, India',
#        'Warangal, Telangana, India'], dtype=object)

# %%
loc = ['Adilabad, Telangana, India', 'Karimnagar, Telangana, India',
       'Khammam, Telangana, India', 'Nizamabad, Telangana, India',
       'Warangal, Telangana, India']

import plotly.express as px

def Plot(Location):
    fig = px.line(Data[Data["Location"]==Location], x="Date", y="AQI", title=Location)
    fig.show()
    return fig

# %%
for location in loc:
    Plot(location)

# %%
# import pandas as pd
# Data = pd.read_csv("AQI_finaldataset.csv")

location_map = {'Adilabad, Telangana, India': 0, 
                'Karimnagar, Telangana, India': 1, 
                'Khammam, Telangana, India': 2, 
                'Nizamabad, Telangana, India': 3, 
                'Warangal, Telangana, India': 4}

# create a new column 'Location_ID' in the dataframe
Data['Location_ID'] = Data['Location'].map(location_map)

# print the mapped values


# inverse mapping to get original location names
Data['Location'] = Data['Location_ID'].map({v: k for k, v in location_map.items()})

# %%
Data = Data.reindex(columns=[ 'Location', 'Location_ID','Date','AQI','CO','NO','NO2','O3','SO2','PM2.5','PM10','NH3'])

# %%
Data.to_csv("AQI_finaldataset.csv", index=False)
